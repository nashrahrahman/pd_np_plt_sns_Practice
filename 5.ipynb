# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
#data visualization with Pandas

# %%
from numpy.random import randint, randn, uniform, sample
df = pd.DataFrame(randn(1000), pd.date_range('2019-06-07', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), pd.date_range('2019-06-07',periods=1000))

# %%
df.head()
# Out:
#                value
# 2019-06-07  0.091052
# 2019-06-08  0.079204
# 2019-06-09  0.244118
# 2019-06-10  0.626650
# 2019-06-11  0.113301

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df['value'].cumsum()
# Out:
# 2019-06-07     0.091052
# 2019-06-08     0.170256
# 2019-06-09     0.414373
# 2019-06-10     1.041023
# 2019-06-11     1.154324
#                 ...
# 2022-02-26   -56.571477
# 2022-02-27   -58.601231
# 2022-02-28   -59.737941
# 2022-03-01   -59.996847
# 2022-03-02   -59.772018
# Freq: D, Name: value, Length: 1000, dtype: float64

# %%
df['value']=df['value'].cumsum()

# %%
df.head()
# Out:
#                value
# 2019-06-07  0.091052
# 2019-06-08  0.170256
# 2019-06-09  0.414373
# 2019-06-10  1.041023
# 2019-06-11  1.154324

# %%
df['value'].cumsum().plot()
# Out:
# <AxesSubplot:>

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %%
ts.cumsum().plot(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
plt.plot(ts)

# %%
plt.plot(ts.cumsum())

# %%
iris= sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
iris.plot()
# Out:
# <AxesSubplot:>

# %%
ax= iris.plot(figsize=(10,7),title="IRIS DATA PLOT")
ax.set_xlabel("index")
ax.set_ylabel('value')
# Out:
# Text(0, 0.5, 'value')

# %%
ts.cumsum().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
iris.iloc[1]
# Out:
# sepal_length       4.9
# sepal_width          3
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 1, dtype: object

# %%
df = iris.drop(["species"],axis=1)

# %%
df.iloc[1]
# Out:
# sepal_length    4.9
# sepal_width     3.0
# petal_length    1.4
# petal_width     0.2
# Name: 1, dtype: float64

# %%
df.iloc[1].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.iloc[1].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df1 = sns.load_dataset("titanic")

# %%
df1.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df1.iloc[1]
# Out:
# survived               1
# pclass                 1
# sex               female
# age                   38
# sibsp                  1
# parch                  0
# fare             71.2833
# embarked               C
# class              First
# who                woman
# adult_male         False
# deck                   C
# embark_town    Cherbourg
# alive                yes
# alone              False
# Name: 1, dtype: object

# %%
df1.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df1['pclass'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2 = pd.DataFrame(randn(10,3),columns=['one','two','three'])

# %%
df2.head()
# Out:
#         one       two     three
# 0  1.020478  1.792363 -0.565068
# 1 -0.030378  1.321643  0.969874
# 2 -0.506887 -0.715728  0.034423
# 3 -1.281134  0.510259 -0.084911
# 4  0.342245 -0.615673 -0.014526

# %%
df2.shape
# Out:
# (10, 3)

# %%
df2
# Out:
#         one       two     three
# 0  1.020478  1.792363 -0.565068
# 1 -0.030378  1.321643  0.969874
# 2 -0.506887 -0.715728  0.034423
# 3 -1.281134  0.510259 -0.084911
# 4  0.342245 -0.615673 -0.014526
# 5 -1.295404  0.438396 -0.882190
# 6  1.213941 -1.017883 -0.659674
# 7  1.243427  1.372778  0.796897
# 8  1.036551 -0.336518  2.654357
# 9 -0.085770  0.097249  1.343549

# %%
df2.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df2.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
iris.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist',stacked=False,bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist',stacked=False,bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df3= iris.drop(['species'],axis=1)

# %%
df3
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df3.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df3.hist(figsize=(10,10),color='r',alpha=0.5)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df3.hist(figsize=(10,10),color='r',alpha=1)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df3.plot.scatter("petal_length","petal_width")
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
df3.plot.scatter("petal_length","petal_width",c='petal_length'd)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
df3.plot.scatter(x='petal_length',y='petal_width',c='petal_length',colormap='viridis',figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
df3.plot.scatter(x='petal_length',y='petal_width',c='petal_length',colormap='viridis',label="label1")
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
df4= df3.iloc[0]

# %%
df4
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df4.plot.pie(figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='0'>

# %%
df3
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df5= df3[0:3]

# %%
df5
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %%
df5=df5.T

# %%
df5.plot.pie(subplots=True, figsize=(20,20))
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
df5.plot.bar(subplots=True, figsize=(10,10))
# Out:
# array([<AxesSubplot:title={'center':'0'}>,
#        <AxesSubplot:title={'center':'1'}>,
#        <AxesSubplot:title={'center':'2'}>], dtype=object)

# %%
df5.plot.pie(subplots = True, figsize = (20, 20), fontsize = 26, autopct = '%.2f')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()
# Out:
# <AxesSubplot:ylabel='Pie Plot'>
